# %%
import matplotlib.pyplot as plt #繪圖函式庫

# %%
#繪製(黃)色X標記
plt.plot([9, 9.2, 9.6, 7.5, 6.7, 7] , [ 9.4, 0.2, 9.2, 9.2, 7.1, 7.4 ], 'yx')
plt.plot([9, 9.2, 9.6, 7.5, 6.7, 7] , [ 9.4, 0.2, 9.2, 9.2, 7.1, 7.4 ], 'yx')
#繪製(綠)色X標記
plt.plot([7.2, 7.3, 7.2, 7.3, 7.2, 7.3, 7.3], [10.3, 10.5, 9.2, 10.2, 9.7, 10.1, 10.1], 'gx')
plt.plot([6.5, 9.0], [7.8, 12.5], 'b--')#繪製黑色
plt.ylabel('H cm')
plt.xlabel('W cm')
plt.legend(('Orange', 'Lemons'), loc='upper right')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [0, 0.3, 0.6, 0.9], 'gx')
plt.plot([1, 2, 3, 4], [0, 0.3, 0.6, 0.9], 'r--')
plt.axis([0, 5, 0, 1])
plt.ylabel('Y')
plt.xlabel('X')
plt.legend(('price', 'passenger'), loc='upper right')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot([1, 2, 3, 4], [0, 0.3, 0.6, 0.9], 'gx')
plt.plot([1, 2, 3, 4], [0, 0.3, 0.6, 0.9], 'r--')

X = 1 + np.arange(30)/10
delta = np.random.uniform(low = -0.1, high = 0.1, size=(30, ))

Y = 0.3 * X - 0.3 + delta
plt.plot(X, Y, 'bo')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
import pandas as pd
from sklearn import linear_model #繪圖函式庫
import matplotlib.pyplot as plt #繪圖函式庫

#read data
dataframe = pd.read_fwf('brain_body.txt')#讀取txt的數據
x_values = dataframe[['Body']] #身體的數據
y_values = dataframe[['Brain']] #大腦的數據

#訓練
body_reg = linear_model.LinearRegression() #使用線性迴歸模型

body_reg.fit(x_values, y_values)
pre = body_reg.predict(x_values)

#訓練預測
print(body_reg.predict(pd.DataFrame(data=[[170]])))

#圖形化
plt.scatter(x_values, y_values)
plt.plot(x_values, pre)
plt.show()
# Out:
# [[96.63965569]]

# %%
import matplotlib.pyplot as plt #繪圖函式庫
import numpy as np #矩陣函式庫
from sklearn import datasets, linear_model #線性迴歸函式庫

#取得糖尿病的數據
diabetes = datasets.load_diabetes()
#只取第三個特徵值BMI
diabetes_X = diabetes.data[:, np.newaxis, 2]
#切分特徵值BMI
diabetes_X_train = diabetes_X[:-20] #切割0到最後20筆特徵給訓練用
diabetes_X_test = diabetes_X[-20:] #切割最後20筆特徵給訓練用
#切分答案
diabetes_y_train = diabetes.target[:-20] #切割0到最後20筆特徵給訓練用
diabetes_y_test = diabetes.target[-20:] #切割最後20筆特徵給訓練用
#計算
regr = linear_model.LinearRegression() #建立線性迴歸

regr.fit(diabetes_X_train, diabetes_y_train) #訓練

#係數
print('Coefficients: \n', regr.coef_)
#均方誤差
print("Mean squared error: %.2f"
     % np.mean((regr.predict(diabetes_X_test) - diabetes_y_test) ** 2))

#顯示方差分數:1是完美預測
print('Variance score: %.2f' % regr.score(diabetes_X_test, diabetes_y_test))

#繪圖
plt.scatter(diabetes_X_test, diabetes_y_test, color = 'black') #畫出測試黑點
plt.plot(diabetes_X_test, regr.predict(diabetes_X_test), color = 'blue',
        linewidth = 3) #劃出測試預測的線性迴歸答案

plt.xticks(())
plt.yticks(())

plt.show() #顯示
# Out:
# Coefficients:
#  [938.23786125]
# Mean squared error: 2548.07
# Variance score: 0.47
